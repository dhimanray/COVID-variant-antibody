# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
wt_cij = np.loadtxt('7BZ5_WT/production_new/mutual_info/mutual_info_avg.txt')

cb = plt.imshow(wt_cij, cmap='nipy_spectral_r',vmax=1.0,vmin=0.0)
#cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
#cbar.ax.tick_params(labelsize=14)
plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('B38 + WT RBD',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_wt_mutual_info.png',dpi=200,bbox_inches='tight')

# %%
wt_cij_err = np.loadtxt('7BZ5_WT/production_new/mutual_info/mutual_info_err.txt')

cb = plt.imshow(wt_cij_err, cmap='nipy_spectral_r',vmax=0.3,vmin=0.0)
#cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
#cbar.ax.tick_params(labelsize=14)
plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('B38 + WT RBD',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_wt_mutual_info_err.png',dpi=200,bbox_inches='tight')

# %%
uk_cij = np.loadtxt('7BZ5_N501Y/production_new/mutual_info/mutual_info_avg.txt')

cb = plt.imshow(uk_cij, cmap='nipy_spectral_r',vmax=1.0,vmin=0.0)
#cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
#cbar.ax.tick_params(labelsize=14)

plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('B38 + N501Y RBD',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_N501Y_mutual_info.png',dpi=200,bbox_inches='tight')

# %%
uk_cij_err = np.loadtxt('7BZ5_N501Y/production_new/mutual_info/mutual_info_err.txt')

cb = plt.imshow(uk_cij_err, cmap='nipy_spectral_r',vmax=0.3,vmin=0.0)
#cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
#cbar.ax.tick_params(labelsize=14)

plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('B38 + N501Y RBD',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_N501Y_mutual_info_err.png',dpi=200,bbox_inches='tight')

# %%
saf_cij = np.loadtxt('7BZ5_South_African/production-new/mutual_info/mutual_info_avg.txt')

cb = plt.imshow(saf_cij, cmap='nipy_spectral_r',vmax=1.0,vmin=0.0)
#cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
#cbar.ax.tick_params(labelsize=14)

plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('B38 + K417N-E484K-N501Y RBD',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_South_African_mutual_info.png',dpi=200,bbox_inches='tight')

# %%
saf_cij_err = np.loadtxt('7BZ5_South_African/production-new/mutual_info/mutual_info_err.txt')

cb = plt.imshow(saf_cij_err, cmap='nipy_spectral_r',vmax=0.3,vmin=0.0)
#cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
#cbar.ax.tick_params(labelsize=14)

plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('B38 + K417N-E484K-N501Y RBD',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_South_African_mutual_info_err.png',dpi=200,bbox_inches='tight')

# %%
ind_cij = np.loadtxt('7BZ5_Indian/production_new/mutual_info/mutual_info_avg.txt')

cb = plt.imshow(ind_cij, cmap='nipy_spectral_r',vmax=1.0,vmin=0.0)
#cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
#cbar.ax.tick_params(labelsize=14)

plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('B38 + L452R-E484Q RBD',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_Indian_mutual_info.png',dpi=200,bbox_inches='tight')

# %%
ind_cij_err = np.loadtxt('7BZ5_Indian/production_new/mutual_info/mutual_info_err.txt')

cb = plt.imshow(ind_cij_err, cmap='nipy_spectral_r',vmax=0.3,vmin=0.0)
#cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
#cbar.ax.tick_params(labelsize=14)

plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('B38 + L452R-E484Q RBD',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_Indian_mutual_info_err.png',dpi=200,bbox_inches='tight')

# %%
delta_cij = np.loadtxt('7BZ5_delta/production/mutual_info/mutual_info_avg.txt')

cb = plt.imshow(delta_cij, cmap='nipy_spectral_r',vmax=1.0,vmin=0.0)
cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
cbar.ax.tick_params(labelsize=14)

plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('B38 + L452R-T478K RBD',fontsize=16)
plt.xlabel('Residue deltaex',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_delta_mutual_info.png',dpi=200,bbox_inches='tight')

# %%
delta_cij_err = np.loadtxt('7BZ5_delta/production/mutual_info/mutual_info_err.txt')

cb = plt.imshow(delta_cij_err, cmap='nipy_spectral_r',vmax=0.3,vmin=0.0)
cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
cbar.ax.tick_params(labelsize=14)

plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('B38 + L452R-T478K RBD',fontsize=16)
plt.xlabel('Residue deltaex',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_delta_mutual_info_err.png',dpi=200,bbox_inches='tight')

# %%
rbd_diff_uk = uk_cij[0:195,0:195] - wt_cij[0:195,0:195]

cb = plt.imshow(rbd_diff_uk, cmap='RdBu',extent=[334,528,528,334],vmax=0.2,vmin=-0.2)

#cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
#cbar.ax.tick_params(labelsize=12)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.axhline(y=501,color='k',ls='--')
plt.xlabel('Residue index',fontsize=16)
plt.ylabel('Residue index',fontsize=16)
plt.title('B38 RBD (N501Y - WT)',fontsize=16)
plt.savefig('mutual_info_figures/7bz5_UK_RBD_diff.png',dpi=200,bbox_inches='tight')

# %%
cross_diff_uk = uk_cij[0:195,195:-1] - wt_cij[0:195,195:-1]

plt.figure(figsize=(5.5,3.5))

cb = plt.imshow(cross_diff_uk, cmap='RdBu',extent=[1,434,528,334],vmax=0.2,vmin=-0.2)

#cbar = plt.colorbar(cb,fraction=0.020, pad=0.1)
#cbar.ax.tick_params(labelsize=12)

xtick_positions=[0,99,167,217,317,367,433]
xtick_labels=[1,100,150,218,100,150,216]
plt.xticks(ticks=xtick_positions, labels=xtick_labels, fontsize=14)


plt.axvline(x=218,color='k')
plt.axvline(x=115,color='k')
plt.axvline(x=218+115,color='k')
plt.text(5,350,'Ch. A: ABD',fontsize=12)
plt.text(120,350,'Ch. A: DD',fontsize=12)
plt.text(5+218,350,'Ch. B: ABD',fontsize=12)
plt.text(120+218,350,'Ch. B: DD',fontsize=12)

plt.yticks(fontsize=14)
plt.axhline(y=501,color='k',ls='--')

plt.ylabel('RBD residue index',fontsize=16)
plt.xlabel('Antibody residue index',fontsize=16)
plt.title('B38 RBD-Antibody (N501Y - WT)',fontsize=16)
plt.savefig('mutual_info_figures/7bz5_UK_RBD_antibody_diff.png',dpi=200,bbox_inches='tight')

# %%
rbd_diff_saf = saf_cij[0:195,0:195] - wt_cij[0:195,0:195]

cb = plt.imshow(rbd_diff_saf, cmap='RdBu',extent=[334,528,528,334],vmax=0.2,vmin=-0.2)

#cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
#cbar.ax.tick_params(labelsize=12)


plt.axhline(y=501,color='k',ls='--')
plt.axhline(y=484,color='k',ls='--')
plt.axhline(y=417,color='k',ls='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Residue index',fontsize=16)
plt.ylabel('Residue index',fontsize=16)
plt.title('B38 RBD (K417N-E484K-N501Y - WT)',fontsize=16)
plt.savefig('mutual_info_figures/7bz5_SA_RBD_diff.png',dpi=200,bbox_inches='tight')

# %%
cross_diff_saf = saf_cij[0:195,195:-1] - wt_cij[0:195,195:-1]

plt.figure(figsize=(5.5,3.5))

cb = plt.imshow(cross_diff_saf, cmap='RdBu',extent=[1,434,528,334],vmax=0.2,vmin=-0.2)

#cbar = plt.colorbar(cb,fraction=0.020, pad=0.1)
#cbar.ax.tick_params(labelsize=12)

xtick_positions=[0,99,167,217,317,367,433]
xtick_labels=[1,100,150,218,100,150,216]
plt.xticks(ticks=xtick_positions, labels=xtick_labels, fontsize=14)


plt.axvline(x=218,color='k')
plt.axvline(x=115,color='k')
plt.axvline(x=218+115,color='k')
plt.text(5,350,'Ch. A: ABD',fontsize=12)
plt.text(120,350,'Ch. A: DD',fontsize=12)
plt.text(5+218,350,'Ch. B: ABD',fontsize=12)
plt.text(120+218,350,'Ch. B: DD',fontsize=12)

plt.yticks(fontsize=14)
plt.axhline(y=501,color='k',ls='--')
plt.axhline(y=484,color='k',ls='--')
plt.axhline(y=417,color='k',ls='--')
plt.ylabel('RBD residue index',fontsize=16)
plt.xlabel('Antibody residue index',fontsize=16)
plt.title('B38 RBD-Antibody (K417N-E484K-N501Y - WT)',fontsize=16)
plt.savefig('mutual_info_figures/7bz5_SA_RBD_antibody_diff.png',dpi=200,bbox_inches='tight')

# %%
rbd_diff_ind = ind_cij[0:195,0:195] - wt_cij[0:195,0:195]

cb = plt.imshow(rbd_diff_ind, cmap='RdBu',extent=[334,528,528,334],vmax=0.2,vmin=-0.2)

#cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
#cbar.ax.tick_params(labelsize=12)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.axhline(y=501,color='k',ls='--')
plt.axhline(y=452,color='k',ls='--')
plt.axhline(y=484,color='k',ls='--')
plt.xlabel('Residue index',fontsize=16)
plt.ylabel('Residue index',fontsize=16)
plt.title('B38 RBD (L452R-E484Q - WT)',fontsize=16)
plt.savefig('mutual_info_figures/7bz5_Indian_RBD_diff.png',dpi=200,bbox_inches='tight')

# %%
cross_diff_ind = ind_cij[0:195,195:-1] - wt_cij[0:195,195:-1]
plt.figure(figsize=(5.5,3.5))

cb = plt.imshow(cross_diff_ind, cmap='RdBu',extent=[1,434,528,334],vmax=0.2,vmin=-0.2)

cbar = plt.colorbar(cb,fraction=0.020, pad=0.1)
cbar.ax.tick_params(labelsize=12)

xtick_positions=[0,99,167,217,317,367,433]
xtick_labels=[1,100,150,218,100,150,216]
plt.xticks(ticks=xtick_positions, labels=xtick_labels, fontsize=14)


plt.axvline(x=218,color='k')
plt.axvline(x=115,color='k')
plt.axvline(x=218+115,color='k')
plt.text(5,350,'Ch. A: ABD',fontsize=12)
plt.text(120,350,'Ch. A: DD',fontsize=12)
plt.text(5+218,350,'Ch. B: ABD',fontsize=12)
plt.text(120+218,350,'Ch. B: DD',fontsize=12)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.axhline(y=452,color='k',ls='--')
plt.axhline(y=484,color='k',ls='--')
plt.ylabel('RBD residue index',fontsize=16)
plt.xlabel('Antibody residue index',fontsize=16)
plt.title('B38 RBD-Antibody (L452R-E484Q - WT)',fontsize=16)
plt.savefig('mutual_info_figures/7bz5_Indian_RBD_antibody_diff.png',dpi=200,bbox_inches='tight')

# %%
rbd_diff_delta = delta_cij[0:195,0:195] - wt_cij[0:195,0:195]

cb = plt.imshow(rbd_diff_delta, cmap='RdBu',extent=[334,528,528,334],vmax=0.2,vmin=-0.2)

cbar = plt.colorbar(cb,fraction=0.046, pad=0.1)
cbar.ax.tick_params(labelsize=12)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.axhline(y=501,color='k',ls='--')
plt.axhline(y=452,color='k',ls='--')
plt.axhline(y=478,color='k',ls='--')
plt.xlabel('Residue index',fontsize=16)
plt.ylabel('Residue index',fontsize=16)
plt.title('B38 RBD (L452R-T478K - WT)',fontsize=16)
plt.savefig('mutual_info_figures/7bz5_delta_RBD_diff.png',dpi=200,bbox_inches='tight')

# %%
cross_diff_delta = delta_cij[0:195,195:-1] - wt_cij[0:195,195:-1]
plt.figure(figsize=(5.5,3.5))

cb = plt.imshow(cross_diff_delta, cmap='RdBu',extent=[1,434,528,334],vmax=0.2,vmin=-0.2)

cbar = plt.colorbar(cb,fraction=0.020, pad=0.1)
cbar.ax.tick_params(labelsize=12)

xtick_positions=[0,99,167,217,317,367,433]
xtick_labels=[1,100,150,218,100,150,216]
plt.xticks(ticks=xtick_positions, labels=xtick_labels, fontsize=14)


plt.axvline(x=218,color='k')
plt.axvline(x=115,color='k')
plt.axvline(x=218+115,color='k')
plt.text(5,350,'Ch. A: ABD',fontsize=12)
plt.text(120,350,'Ch. A: DD',fontsize=12)
plt.text(5+218,350,'Ch. B: ABD',fontsize=12)
plt.text(120+218,350,'Ch. B: DD',fontsize=12)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.axhline(y=452,color='k',ls='--')
plt.axhline(y=478,color='k',ls='--')
plt.ylabel('RBD residue index',fontsize=16)
plt.xlabel('Antibody residue index',fontsize=16)
plt.title('B38 RBD-Antibody (L452R-T478K - WT)',fontsize=16)
plt.savefig('mutual_info_figures/7bz5_delta_RBD_antibody_diff.png',dpi=200,bbox_inches='tight')

# %%
wt_bc = np.loadtxt('7BZ5_WT/production_new/mutual_info/centrality.txt')
wt_bc /= np.sum(wt_bc)

uk_bc = np.loadtxt('7BZ5_N501Y/production_new/mutual_info/centrality.txt')
uk_bc /= np.sum(uk_bc)

saf_bc = np.loadtxt('7BZ5_South_African/production-new/mutual_info/centrality.txt')
saf_bc /= np.sum(saf_bc)

ind_bc = np.loadtxt('7BZ5_Indian/production_new/mutual_info/centrality.txt')
ind_bc /= np.sum(ind_bc)

delta_bc = np.loadtxt('7BZ5_delta/production/mutual_info/centrality.txt')
delta_bc /= np.sum(delta_bc)

# %%
print(wt_bc)
# Out:
# [0.00000000e+00 1.00972738e-05 5.69486241e-04 5.45252784e-04
#  5.36165237e-04 5.50637996e-04 5.82612697e-04 7.35081530e-04
#  3.15371517e-04 1.03665344e-04 2.41324843e-04 1.82760655e-04
#  2.50748965e-04 4.47645804e-04 4.18363710e-04 5.54003754e-04
#  6.74161312e-04 6.51610734e-04 4.76019143e-03 5.12402986e-03
#  4.71643658e-03 4.19407095e-03 2.76362383e-03 2.59028730e-03
#  3.16044669e-03 2.80502265e-03 2.28905196e-03 2.16048001e-03
#  1.22648219e-03 7.51910320e-04 6.44206067e-04 2.59163360e-05
#  6.25694398e-04 9.89532829e-05 0.00000000e+00 3.36575792e-07
#  4.72888988e-04 7.74460898e-04 0.00000000e+00 1.11204642e-03
#  1.31331874e-03 2.03964930e-04 6.73151585e-05 8.78462818e-05
#  1.11743163e-04 1.07636938e-03 9.43421946e-04 8.69038696e-04
#  6.83585434e-04 4.52357865e-04 1.30254832e-04 6.15933700e-05
#  2.12042749e-04 2.81713938e-04 4.29134135e-04 6.07519305e-04
#  8.48844148e-04 1.44424672e-03 1.53108328e-03 1.23355028e-03
# ...

# %%
x = np.arange(len(wt_bc))

uk_bc_diff = uk_bc - wt_bc
saf_bc_diff = saf_bc - wt_bc
ind_bc_diff = ind_bc - wt_bc
delta_bc_diff = delta_bc - wt_bc

# %%
#RBD part
plt.plot(x[0:195]+334,uk_bc_diff[0:195],label='UK',color='b')
plt.plot(x[0:195]+334,saf_bc_diff[0:195],label='SA',color='r')
plt.plot(x[0:195]+334,ind_bc_diff[0:195],label='Ind',color='k')
plt.plot(x[0:195]+334,delta_bc_diff[0:195],label='delta',color='g')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Residue index',fontsize=16)
plt.ylabel('Centrality difference',fontsize=16)
#plt.legend(fontsize=14)
plt.axvline(x=501,color='b',ls='--')
plt.axvline(x=484,color='magenta',ls='--')
plt.axvline(x=417,color='r',ls='--')
plt.axvline(x=452,color='k',ls='--')
plt.axvline(x=478,color='green',ls='--')
plt.savefig('mutual_info_figures/7bz5_RBD_centrality_diff.pdf',bbox_inches='tight')

# %%
#Antibody part
plt.plot(x[195:-1]-195,uk_bc_diff[195:-1],label='UK',color='b')
plt.plot(x[195:-1]-195,saf_bc_diff[195:-1],label='SA',color='r')
plt.plot(x[195:-1]-195,ind_bc_diff[195:-1],label='Ind',color='k')
plt.plot(x[195:-1]-195,delta_bc_diff[195:-1],label='delta',color='g')

xtick_positions=[0,99,167,217,317,367,433]
xtick_labels=[1,100,150,218,100,150,216]
plt.xticks(ticks=xtick_positions, labels=xtick_labels, fontsize=14)


plt.axvline(x=218,color='k')
plt.axvline(x=115,color='k')
plt.axvline(x=218+115,color='k')
plt.text(5,0.015,'Ch. A: ABD',fontsize=12)
plt.text(120,0.015,'Ch. A: DD',fontsize=12)
plt.text(5+218,0.015,'Ch. B: ABD',fontsize=12)
plt.text(120+218,0.015,'Ch. B: DD',fontsize=12)

plt.yticks(fontsize=14)
plt.xlabel('Residue index',fontsize=16)
plt.ylabel('Centrality difference',fontsize=16)
#plt.legend(fontsize=14)
plt.savefig('mutual_info_figures/7bz5_Antibody_centrality_diff.pdf',bbox_inches='tight')

# %%
contact_wt = np.loadtxt('7BZ5_WT/production_new/mutual_info/contact_matrix_plot.txt')
plt.imshow(contact_wt,cmap='Blues')
plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('7BZ5 WT',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_wt_contacts.png',dpi=200,bbox_inches='tight')

# %%
contact_uk = np.loadtxt('7BZ5_N501Y/production_new/mutual_info/contact_matrix_plot.txt')
plt.imshow(contact_uk,cmap='Blues')
plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('7BZ5 UK',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_N501Y_contacts.png',dpi=200,bbox_inches='tight')

# %%
contact_saf = np.loadtxt('7BZ5_South_African/production-new/mutual_info/contact_matrix_plot.txt')
plt.imshow(contact_saf,cmap='Blues')
plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('7BZ5 SA',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_SA_contacts.png',dpi=200,bbox_inches='tight')

# %%
contact_diff_uk = abs(contact_uk - contact_wt)
plt.imshow(contact_diff_uk,cmap='Blues')
plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('7BZ5 UK',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_N501Y_contact_diff.png',dpi=200,bbox_inches='tight')

# %%
contact_diff_saf = abs(contact_saf - contact_wt)
plt.imshow(contact_diff_saf,cmap='Blues')
plt.axvline(x=195,c='k',ls='--')
plt.axhline(y=195,c='k',ls='--')
plt.yticks(color='white')
plt.xticks(fontsize=14)
plt.title('7BZ5 SA',fontsize=16)
plt.xlabel('Residue index',fontsize=16)
plt.text(-50,120,'RBD',fontsize=16,rotation='vertical')
plt.text(-50,520,'Antibody',fontsize=16,rotation='vertical')
plt.savefig('mutual_info_figures/7bz5_SA_contacts_diff.png',dpi=200,bbox_inches='tight')

# %%
for i in range(len(contact_diff_uk)):
    for j in range(len(contact_diff_uk)):
        if i >= 195 and j < 195:
            if contact_diff_uk[i,j] == 1:
                print(i,j+334)
# Out:
# 247 416
# 251 416
# 251 421
# 294 455
# 295 456
# 295 489
# 295 490
# 295 493
# 440 502
# 441 500
# 441 501
# 441 502
# 442 501
# 443 495
# 443 496
# 443 498
# 443 505
# 444 501
# 445 494
# 445 505
# 505 505
# 506 403
# 506 505

# %%
np.savetxt('mutual_info_figures/uk_BC_ratio.dat',uk_bc_diff*1E+3,fmt='%0.2f') 
#multiply by 1000 to make a bigger number for the resoultion of pdb beta column is not high
np.savetxt('mutual_info_figures/saf_BC_ratio.dat',saf_bc_diff*1E+3,fmt='%0.2f')
np.savetxt('mutual_info_figures/ind_BC_ratio.dat',ind_bc_diff*1E+3,fmt='%0.2f')
np.savetxt('mutual_info_figures/delta_BC_ratio.dat',delta_bc_diff*1E+3,fmt='%0.2f')

# %%
#average cross correlation change
avg = [np.sum(cross_diff_uk)/cross_diff_uk.size,np.sum(cross_diff_saf)/cross_diff_saf.size,
       np.sum(cross_diff_ind)/cross_diff_ind.size, np.sum(cross_diff_delta)/cross_diff_delta.size]
labels = ['N501Y','K417N\nE484K\nN501Y','L452R\nE484Q', 'L452R\nT478K']

colors = ['b','r','gray','g']

plt.bar(labels,avg,capsize=20.0,color=colors)
plt.xticks(rotation=60)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.axhline(y=0,color='k',ls='--')
plt.title('B38 + RBD',fontsize=16)
plt.ylabel('$<\Delta$ Cross-correlation$>$',fontsize=16)
plt.savefig('mutual_info_figures/7BZ5_cross_corr_avg.pdf',bbox_inches='tight')
