# %%
import numpy as np
import matplotlib.pyplot as plt
import uncertainties as unc  
import uncertainties.unumpy as unumpy

# %%
wt_rmsf_1 = np.loadtxt('7BZ5_WT/production_new/rmsf/rmsf_100-200ns.dat')
wt_rmsf_2 = np.loadtxt('7BZ5_WT/production_new/rmsf/rmsf_200-300ns.dat')
wt_rmsf_3 = np.loadtxt('7BZ5_WT/production_new/rmsf/rmsf_300-400ns.dat')
wt_rmsf_4 = np.loadtxt('7BZ5_WT/production_new/rmsf/rmsf_400-500ns.dat')

wt_rmsf_mean = np.zeros(len(wt_rmsf_1))
wt_rmsf_std = np.zeros(len(wt_rmsf_1))
for i in range(len(wt_rmsf_1)):
    wt_rmsf_mean[i] = np.mean(np.array([wt_rmsf_1[i,1],wt_rmsf_2[i,1],wt_rmsf_3[i,1],wt_rmsf_4[i,1]]))*10
    wt_rmsf_std[i] = np.std(np.array([wt_rmsf_1[i,1],wt_rmsf_2[i,1],wt_rmsf_3[i,1],wt_rmsf_4[i,1]]))*10

x = wt_rmsf_1[:,0]

# %%
uk_rmsf_1 = np.loadtxt('7BZ5_N501Y/production_new/rmsf/rmsf_100-200ns.dat')
uk_rmsf_2 = np.loadtxt('7BZ5_N501Y/production_new/rmsf/rmsf_200-300ns.dat')
uk_rmsf_3 = np.loadtxt('7BZ5_N501Y/production_new/rmsf/rmsf_300-400ns.dat')
uk_rmsf_4 = np.loadtxt('7BZ5_N501Y/production_new/rmsf/rmsf_400-500ns.dat')

uk_rmsf_mean = np.zeros(len(uk_rmsf_1))
uk_rmsf_std = np.zeros(len(uk_rmsf_1))
for i in range(len(uk_rmsf_1)):
    uk_rmsf_mean[i] = np.mean(np.array([uk_rmsf_1[i,1],uk_rmsf_2[i,1],uk_rmsf_3[i,1],uk_rmsf_4[i,1]]))*10
    uk_rmsf_std[i] = np.std(np.array([uk_rmsf_1[i,1],uk_rmsf_2[i,1],uk_rmsf_3[i,1],uk_rmsf_4[i,1]]))*10

x = uk_rmsf_1[:,0]

# %%
saf_rmsf_1 = np.loadtxt('7BZ5_South_African/production-new/rmsf/rmsf_100-200ns.dat')
saf_rmsf_2 = np.loadtxt('7BZ5_South_African/production-new/rmsf/rmsf_200-300ns.dat')
saf_rmsf_3 = np.loadtxt('7BZ5_South_African/production-new/rmsf/rmsf_300-400ns.dat')
saf_rmsf_4 = np.loadtxt('7BZ5_South_African/production-new/rmsf/rmsf_400-500ns.dat')

saf_rmsf_mean = np.zeros(len(saf_rmsf_1))
saf_rmsf_std = np.zeros(len(saf_rmsf_1))
for i in range(len(saf_rmsf_1)):
    saf_rmsf_mean[i] = np.mean(np.array([saf_rmsf_1[i,1],saf_rmsf_2[i,1],saf_rmsf_3[i,1],saf_rmsf_4[i,1]]))*10
    saf_rmsf_std[i] = np.std(np.array([saf_rmsf_1[i,1],saf_rmsf_2[i,1],saf_rmsf_3[i,1],saf_rmsf_4[i,1]]))*10

x = saf_rmsf_1[:,0]

# %%
ind_rmsf_1 = np.loadtxt('7BZ5_Indian/production_new/rmsf/rmsf_100-200ns.dat')
ind_rmsf_2 = np.loadtxt('7BZ5_Indian/production_new/rmsf/rmsf_200-300ns.dat')
ind_rmsf_3 = np.loadtxt('7BZ5_Indian/production_new/rmsf/rmsf_300-400ns.dat')
ind_rmsf_4 = np.loadtxt('7BZ5_Indian/production_new/rmsf/rmsf_400-500ns.dat')

ind_rmsf_mean = np.zeros(len(ind_rmsf_1))
ind_rmsf_std = np.zeros(len(ind_rmsf_1))
for i in range(len(ind_rmsf_1)):
    ind_rmsf_mean[i] = np.mean(np.array([ind_rmsf_1[i,1],ind_rmsf_2[i,1],ind_rmsf_3[i,1],ind_rmsf_4[i,1]]))*10
    ind_rmsf_std[i] = np.std(np.array([ind_rmsf_1[i,1],ind_rmsf_2[i,1],ind_rmsf_3[i,1],ind_rmsf_4[i,1]]))*10

x = ind_rmsf_1[:,0]

# %%
delta_rmsf_1 = np.loadtxt('7BZ5_delta/production/rmsf/rmsf_100-200ns.dat')
delta_rmsf_2 = np.loadtxt('7BZ5_delta/production/rmsf/rmsf_200-300ns.dat')
delta_rmsf_3 = np.loadtxt('7BZ5_delta/production/rmsf/rmsf_300-400ns.dat')
delta_rmsf_4 = np.loadtxt('7BZ5_delta/production/rmsf/rmsf_400-500ns.dat')

delta_rmsf_mean = np.zeros(len(delta_rmsf_1))
delta_rmsf_std = np.zeros(len(delta_rmsf_1))
for i in range(len(delta_rmsf_1)):
    delta_rmsf_mean[i] = np.mean(np.array([delta_rmsf_1[i,1],delta_rmsf_2[i,1],delta_rmsf_3[i,1],delta_rmsf_4[i,1]]))*10
    delta_rmsf_std[i] = np.std(np.array([delta_rmsf_1[i,1],delta_rmsf_2[i,1],delta_rmsf_3[i,1],delta_rmsf_4[i,1]]))*10

x = delta_rmsf_1[:,0]

# %%
plt.plot(x[0:195],wt_rmsf_mean[0:195],color='orange',ls='-',label='WT')
plt.fill_between(x[0:195], wt_rmsf_mean[0:195] - wt_rmsf_std[0:195],wt_rmsf_mean[0:195] + wt_rmsf_std[0:195], facecolor='orange',alpha=0.5)

plt.plot(x[0:195],uk_rmsf_mean[0:195],'b-',label='N501Y')
plt.fill_between(x[0:195], uk_rmsf_mean[0:195] - uk_rmsf_std[0:195],uk_rmsf_mean[0:195] + uk_rmsf_std[0:195], facecolor='xkcd:lightblue')

plt.plot(x[0:195],saf_rmsf_mean[0:195],'r-',label='K417N/E484K/N501Y')
plt.fill_between(x[0:195], saf_rmsf_mean[0:195] - saf_rmsf_std[0:195],saf_rmsf_mean[0:195] + saf_rmsf_std[0:195], facecolor='pink')

plt.plot(x[0:195],ind_rmsf_mean[0:195],'k-',label='L452R/E484Q')
plt.fill_between(x[0:195], ind_rmsf_mean[0:195] - ind_rmsf_std[0:195],ind_rmsf_mean[0:195] + ind_rmsf_std[0:195], facecolor='gray')

plt.plot(x[0:195],delta_rmsf_mean[0:195],'g-',label='L452R/T478K')
plt.fill_between(x[0:195], delta_rmsf_mean[0:195] - delta_rmsf_std[0:195],delta_rmsf_mean[0:195] + delta_rmsf_std[0:195], facecolor='xkcd:lightgreen' )


#plt.legend(fontsize=14,ncol=2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Residue index',fontsize=16)
plt.ylabel('RMSF ($\AA$)',fontsize=16)
plt.axvline(x=501,color='b',ls='--')
plt.axvline(x=484,color='magenta',ls='--')
plt.axvline(x=417,color='r',ls='--')
plt.axvline(x=452,color='k',ls='--')
plt.axvline(x=478,color='green',ls='--')
#plt.ylim(0,9)
plt.savefig('rmsf_figures/7BZ5_RBD_rmsf.pdf',bbox_inches='tight')

# %%
xx = np.arange(433)

plt.plot(xx,wt_rmsf_mean[195:-1],color='orange',ls='-',label='WT')
plt.fill_between(xx, wt_rmsf_mean[195:-1] - wt_rmsf_std[195:-1],wt_rmsf_mean[195:-1] + wt_rmsf_std[195:-1], facecolor='orange',alpha=0.5)

plt.plot(xx,uk_rmsf_mean[195:-1],'b-',label='UK Variant')
plt.fill_between(xx, uk_rmsf_mean[195:-1] - uk_rmsf_std[195:-1],uk_rmsf_mean[195:-1] + uk_rmsf_std[195:-1], facecolor='xkcd:lightblue')

plt.plot(xx,saf_rmsf_mean[195:-1],'r-',label='SA Variant')
plt.fill_between(xx, saf_rmsf_mean[195:-1] - saf_rmsf_std[195:-1],saf_rmsf_mean[195:-1] + saf_rmsf_std[195:-1], facecolor='pink')

plt.plot(xx,ind_rmsf_mean[195:-1],'k-',label='Ind Variant')
plt.fill_between(xx, ind_rmsf_mean[195:-1] - ind_rmsf_std[195:-1],ind_rmsf_mean[195:-1] + ind_rmsf_std[195:-1], facecolor='gray')

plt.plot(xx,delta_rmsf_mean[195:-1],'g-',label='delta Variant')
plt.fill_between(xx, delta_rmsf_mean[195:-1] - delta_rmsf_std[195:-1],delta_rmsf_mean[195:-1] + delta_rmsf_std[195:-1], facecolor='xkcd:lightgreen')


#plt.legend(fontsize=14)
xtick_positions=[0,99,167,217,317,367,433]
xtick_labels=[1,100,150,218,100,150,216]
plt.xticks(ticks=xtick_positions, labels=xtick_labels, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Residue index',fontsize=16)
plt.ylabel('RMSF ($\AA$)',fontsize=16)
plt.axvline(x=218,color='g')
plt.axvline(x=115)
plt.axvline(x=218+115)
plt.text(5,7,'Chain A',fontsize=16)
plt.text(120,7,'Chain A',fontsize=16)
plt.text(5+218,7,'Chain B',fontsize=16)
plt.text(120+218,7,'Chain B',fontsize=16)
plt.text(20,6,'ABD',fontsize=16)
plt.text(150,6,'DD',fontsize=16)
plt.text(20+218,6,'ABD',fontsize=16)
plt.text(150+218,6,'DD',fontsize=16)
plt.savefig('rmsf_figures/7BZ5_Antibody_rmsf.pdf',bbox_inches='tight')

# %%
xxx = unumpy.uarray(( 50.0, 5.0))
yyy = unumpy.uarray(( 10.0, 2.0))

zzz = xxx/yyy
print(zzz)
print(unumpy.nominal_values(zzz))
print(unumpy.std_devs(zzz))
# Out:
# 5.0+/-1.1
# 5.0
# 1.118033988749895
# /home/dhiman/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Obsolete: uarray() should now be called with two arguments. Code can be automatically updated with python -m uncertainties.1to2 -w ProgramDirectory.
#   """Entry point for launching an IPython kernel.
# /home/dhiman/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Obsolete: uarray() should now be called with two arguments. Code can be automatically updated with python -m uncertainties.1to2 -w ProgramDirectory.

# %%
wt = unumpy.uarray(( wt_rmsf_mean, wt_rmsf_std ))
uk = unumpy.uarray(( uk_rmsf_mean, uk_rmsf_std ))
saf = unumpy.uarray(( saf_rmsf_mean, saf_rmsf_std ))
ind = unumpy.uarray(( ind_rmsf_mean, ind_rmsf_std ))
delta = unumpy.uarray(( delta_rmsf_mean, delta_rmsf_std ))

uk_ratio = uk/wt
uk_mean_ratio = unumpy.nominal_values(uk_ratio)
uk_std_ratio = unumpy.std_devs(uk_ratio)

saf_ratio = saf/wt
saf_mean_ratio = unumpy.nominal_values(saf_ratio)
saf_std_ratio = unumpy.std_devs(saf_ratio)

ind_ratio = ind/wt
ind_mean_ratio = unumpy.nominal_values(ind_ratio)
ind_std_ratio = unumpy.std_devs(ind_ratio)

delta_ratio = delta/wt
delta_mean_ratio = unumpy.nominal_values(delta_ratio)
delta_std_ratio = unumpy.std_devs(delta_ratio)
# Out:
# /home/dhiman/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Obsolete: uarray() should now be called with two arguments. Code can be automatically updated with python -m uncertainties.1to2 -w ProgramDirectory.
#   """Entry point for launching an IPython kernel.
# /home/dhiman/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Obsolete: uarray() should now be called with two arguments. Code can be automatically updated with python -m uncertainties.1to2 -w ProgramDirectory.
#
# /home/dhiman/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Obsolete: uarray() should now be called with two arguments. Code can be automatically updated with python -m uncertainties.1to2 -w ProgramDirectory.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
plt.plot(x[0:195],ind_mean_ratio[0:195],'k-',label='L452R/E484Q')
plt.fill_between(x[0:195], ind_mean_ratio[0:195] - ind_std_ratio[0:195],ind_mean_ratio[0:195] + ind_std_ratio[0:195], facecolor='gray')

#plt.plot(x[0:195],saf_mean_ratio[0:195],'r-',label='K417N/E484K/N501Y')
#plt.fill_between(x[0:195], saf_mean_ratio[0:195] - saf_std_ratio[0:195],saf_mean_ratio[0:195] + saf_std_ratio[0:195], facecolor='pink')

#plt.plot(x[0:195],uk_mean_ratio[0:195],'b-',label='N501Y')
#plt.fill_between(x[0:195], uk_mean_ratio[0:195] - uk_std_ratio[0:195],uk_mean_ratio[0:195] + uk_std_ratio[0:195], facecolor='xkcd:lightblue')

#plt.plot(x[0:195],delta_mean_ratio[0:195],'g-',label='L452R/T478K')
#plt.fill_between(x[0:195], delta_mean_ratio[0:195] - delta_std_ratio[0:195],delta_mean_ratio[0:195] + delta_std_ratio[0:195],  facecolor='xkcd:lightgreen',alpha=0.5)


#plt.legend(fontsize=14,ncol=2)
plt.ylim(0,2.5)
#plt.xticks(fontsize=14)
plt.xticks([])
plt.yticks(fontsize=14)
#plt.xlabel('Residue index',fontsize=16)
#plt.ylabel('RMSF Ratio',fontsize=16)
#plt.axvline(x=501,color='b',ls='--')
plt.axvline(x=484,color='magenta',ls='--')
#plt.axvline(x=417,color='r',ls='--')
plt.axvline(x=452,color='k',ls='--')
#plt.axvline(x=478,color='green',ls='--')
plt.axhline(y=1.00,color='g',ls='--')
plt.savefig('rmsf_figures/7BZ5_RBD_rmsf_ratio_ind.pdf',bbox_inches='tight')

# %%
#plt.plot(x[0:195],ind_mean_ratio[0:195],'k-',label='L452R/E484Q')
#plt.fill_between(x[0:195], ind_mean_ratio[0:195] - ind_std_ratio[0:195],ind_mean_ratio[0:195] + ind_std_ratio[0:195], facecolor='gray')

plt.plot(x[0:195],saf_mean_ratio[0:195],'r-',label='K417N/E484K/N501Y')
plt.fill_between(x[0:195], saf_mean_ratio[0:195] - saf_std_ratio[0:195],saf_mean_ratio[0:195] + saf_std_ratio[0:195], facecolor='pink')

#plt.plot(x[0:195],uk_mean_ratio[0:195],'b-',label='N501Y')
#plt.fill_between(x[0:195], uk_mean_ratio[0:195] - uk_std_ratio[0:195],uk_mean_ratio[0:195] + uk_std_ratio[0:195], facecolor='xkcd:lightblue')

#plt.plot(x[0:195],delta_mean_ratio[0:195],'g-',label='L452R/T478K')
#plt.fill_between(x[0:195], delta_mean_ratio[0:195] - delta_std_ratio[0:195],delta_mean_ratio[0:195] + delta_std_ratio[0:195],  facecolor='xkcd:lightgreen',alpha=0.5)


#plt.legend(fontsize=14,ncol=2)
plt.ylim(0,2.5)
#plt.xticks(fontsize=14)
plt.xticks([])
plt.yticks(fontsize=14)
#plt.xlabel('Residue index',fontsize=16)
#plt.ylabel('RMSF Ratio',fontsize=16)
plt.axvline(x=501,color='b',ls='--')
plt.axvline(x=484,color='magenta',ls='--')
plt.axvline(x=417,color='r',ls='--')
#plt.axvline(x=452,color='k',ls='--')
#plt.axvline(x=478,color='green',ls='--')
plt.axhline(y=1.00,color='g',ls='--')
plt.savefig('rmsf_figures/7BZ5_RBD_rmsf_ratio_saf.pdf',bbox_inches='tight')

# %%
#plt.plot(x[0:195],ind_mean_ratio[0:195],'k-',label='L452R/E484Q')
#plt.fill_between(x[0:195], ind_mean_ratio[0:195] - ind_std_ratio[0:195],ind_mean_ratio[0:195] + ind_std_ratio[0:195], facecolor='gray')

#plt.plot(x[0:195],saf_mean_ratio[0:195],'r-',label='K417N/E484K/N501Y')
#plt.fill_between(x[0:195], saf_mean_ratio[0:195] - saf_std_ratio[0:195],saf_mean_ratio[0:195] + saf_std_ratio[0:195], facecolor='pink')

plt.plot(x[0:195],uk_mean_ratio[0:195],'b-',label='N501Y')
plt.fill_between(x[0:195], uk_mean_ratio[0:195] - uk_std_ratio[0:195],uk_mean_ratio[0:195] + uk_std_ratio[0:195], facecolor='xkcd:lightblue')

#plt.plot(x[0:195],delta_mean_ratio[0:195],'g-',label='L452R/T478K')
#plt.fill_between(x[0:195], delta_mean_ratio[0:195] - delta_std_ratio[0:195],delta_mean_ratio[0:195] + delta_std_ratio[0:195],  facecolor='xkcd:lightgreen',alpha=0.5)


#plt.legend(fontsize=14,ncol=2)
plt.ylim(0,2.5)
#plt.xticks(fontsize=14)
plt.xticks([])
plt.yticks(fontsize=14)
#plt.xlabel('Residue index',fontsize=16)
#plt.ylabel('RMSF Ratio',fontsize=16)
plt.axvline(x=501,color='b',ls='--')
#plt.axvline(x=484,color='magenta',ls='--')
#plt.axvline(x=417,color='r',ls='--')
#plt.axvline(x=452,color='k',ls='--')
#plt.axvline(x=478,color='green',ls='--')
plt.axhline(y=1.00,color='g',ls='--')
plt.savefig('rmsf_figures/7BZ5_RBD_rmsf_ratio_uk.pdf',bbox_inches='tight')

# %%
#plt.plot(x[0:195],ind_mean_ratio[0:195],'k-',label='L452R/E484Q')
#plt.fill_between(x[0:195], ind_mean_ratio[0:195] - ind_std_ratio[0:195],ind_mean_ratio[0:195] + ind_std_ratio[0:195], facecolor='gray')

#plt.plot(x[0:195],saf_mean_ratio[0:195],'r-',label='K417N/E484K/N501Y')
#plt.fill_between(x[0:195], saf_mean_ratio[0:195] - saf_std_ratio[0:195],saf_mean_ratio[0:195] + saf_std_ratio[0:195], facecolor='pink')

#plt.plot(x[0:195],uk_mean_ratio[0:195],'b-',label='N501Y')
#plt.fill_between(x[0:195], uk_mean_ratio[0:195] - uk_std_ratio[0:195],uk_mean_ratio[0:195] + uk_std_ratio[0:195], facecolor='xkcd:lightblue')

plt.plot(x[0:195],delta_mean_ratio[0:195],'g-',label='L452R/T478K')
plt.fill_between(x[0:195], delta_mean_ratio[0:195] - delta_std_ratio[0:195],delta_mean_ratio[0:195] + delta_std_ratio[0:195],  facecolor='xkcd:lightgreen',alpha=0.5)


#plt.legend(fontsize=14,ncol=2)
plt.ylim(0,2.5)
plt.xticks(fontsize=14)
#plt.xticks([])
plt.yticks(fontsize=14)
#plt.xlabel('Residue index',fontsize=16)
#plt.ylabel('RMSF Ratio',fontsize=16)
#plt.axvline(x=501,color='b',ls='--')
#plt.axvline(x=484,color='magenta',ls='--')
#plt.axvline(x=417,color='r',ls='--')
plt.axvline(x=452,color='k',ls='--')
plt.axvline(x=478,color='green',ls='--')
plt.axhline(y=1.00,color='g',ls='--')
plt.savefig('rmsf_figures/7BZ5_RBD_rmsf_ratio_delta.pdf',bbox_inches='tight')

# %%
xx = np.arange(433)

plt.plot(xx,ind_mean_ratio[195:-1],'k-',label='Ind Variant')
plt.fill_between(xx, ind_mean_ratio[195:-1] - ind_std_ratio[195:-1],ind_mean_ratio[195:-1] + ind_std_ratio[195:-1], facecolor='gray')

#plt.plot(xx,uk_mean_ratio[195:-1],'b-',label='UK Variant')
#plt.fill_between(xx, uk_mean_ratio[195:-1] - uk_std_ratio[195:-1],uk_mean_ratio[195:-1] + uk_std_ratio[195:-1], facecolor='xkcd:lightblue')

#plt.plot(xx,saf_mean_ratio[195:-1],'r-',label='SA Variant')
#plt.fill_between(xx, saf_mean_ratio[195:-1] - saf_std_ratio[195:-1],saf_mean_ratio[195:-1] + saf_std_ratio[195:-1], facecolor='pink')

#plt.plot(xx,delta_mean_ratio[195:-1],'g-',label='delta Variant')
#plt.fill_between(xx, delta_mean_ratio[195:-1] - delta_std_ratio[195:-1],delta_mean_ratio[195:-1] + delta_std_ratio[195:-1], facecolor='xkcd:lightgreen')


#plt.legend(fontsize=14)
plt.ylim(0,3.5)
#xtick_positions=[0,99,167,217,317,367,433]
#xtick_labels=[1,100,150,218,100,150,216]
#plt.xticks(ticks=xtick_positions, labels=xtick_labels, fontsize=14)
plt.xticks([])
plt.yticks(fontsize=14)
#plt.xlabel('Residue index',fontsize=16)
#plt.ylabel('RMSF Ratio',fontsize=16)

plt.axvline(x=218,color='g')
plt.axvline(x=115)
plt.axvline(x=218+115)
plt.text(5,3,'Chain A',fontsize=16)
plt.text(120,3,'Chain A',fontsize=16)
plt.text(5+218,3,'Chain B',fontsize=16)
plt.text(120+218,3,'Chain B',fontsize=16)
plt.text(20,2.7,'ABD',fontsize=16)
plt.text(150,2.7,'DD',fontsize=16)
plt.text(20+218,2.7,'ABD',fontsize=16)
plt.text(150+218,2.7,'DD',fontsize=16)

plt.axhline(y=1.00,color='g',ls='--')
plt.savefig('rmsf_figures/7BZ5_Antibody_rmsf_ratio_ind.pdf',bbox_inches='tight')

# %%
xx = np.arange(433)

#plt.plot(xx,ind_mean_ratio[195:-1],'k-',label='Ind Variant')
#plt.fill_between(xx, ind_mean_ratio[195:-1] - ind_std_ratio[195:-1],ind_mean_ratio[195:-1] + ind_std_ratio[195:-1], facecolor='gray')

plt.plot(xx,uk_mean_ratio[195:-1],'b-',label='UK Variant')
plt.fill_between(xx, uk_mean_ratio[195:-1] - uk_std_ratio[195:-1],uk_mean_ratio[195:-1] + uk_std_ratio[195:-1], facecolor='xkcd:lightblue')

#plt.plot(xx,saf_mean_ratio[195:-1],'r-',label='SA Variant')
#plt.fill_between(xx, saf_mean_ratio[195:-1] - saf_std_ratio[195:-1],saf_mean_ratio[195:-1] + saf_std_ratio[195:-1], facecolor='pink')

#plt.plot(xx,delta_mean_ratio[195:-1],'g-',label='delta Variant')
#plt.fill_between(xx, delta_mean_ratio[195:-1] - delta_std_ratio[195:-1],delta_mean_ratio[195:-1] + delta_std_ratio[195:-1], facecolor='xkcd:lightgreen')


#plt.legend(fontsize=14)
plt.ylim(0,3.5)
#xtick_positions=[0,99,167,217,317,367,433]
#xtick_labels=[1,100,150,218,100,150,216]
#plt.xticks(ticks=xtick_positions, labels=xtick_labels, fontsize=14)
plt.xticks([])
plt.yticks(fontsize=14)
#plt.xlabel('Residue index',fontsize=16)
#plt.ylabel('RMSF Ratio',fontsize=16)

plt.axvline(x=218,color='g')
plt.axvline(x=115)
plt.axvline(x=218+115)
plt.text(5,3,'Chain A',fontsize=16)
plt.text(120,3,'Chain A',fontsize=16)
plt.text(5+218,3,'Chain B',fontsize=16)
plt.text(120+218,3,'Chain B',fontsize=16)
plt.text(20,2.7,'ABD',fontsize=16)
plt.text(150,2.7,'DD',fontsize=16)
plt.text(20+218,2.7,'ABD',fontsize=16)
plt.text(150+218,2.7,'DD',fontsize=16)

plt.axhline(y=1.00,color='g',ls='--')
plt.savefig('rmsf_figures/7BZ5_Antibody_rmsf_ratio_uk.pdf',bbox_inches='tight')

# %%
xx = np.arange(433)

#plt.plot(xx,ind_mean_ratio[195:-1],'k-',label='Ind Variant')
#plt.fill_between(xx, ind_mean_ratio[195:-1] - ind_std_ratio[195:-1],ind_mean_ratio[195:-1] + ind_std_ratio[195:-1], facecolor='gray')

#plt.plot(xx,uk_mean_ratio[195:-1],'b-',label='UK Variant')
#plt.fill_between(xx, uk_mean_ratio[195:-1] - uk_std_ratio[195:-1],uk_mean_ratio[195:-1] + uk_std_ratio[195:-1], facecolor='xkcd:lightblue')

plt.plot(xx,saf_mean_ratio[195:-1],'r-',label='SA Variant')
plt.fill_between(xx, saf_mean_ratio[195:-1] - saf_std_ratio[195:-1],saf_mean_ratio[195:-1] + saf_std_ratio[195:-1], facecolor='pink')

#plt.plot(xx,delta_mean_ratio[195:-1],'g-',label='delta Variant')
#plt.fill_between(xx, delta_mean_ratio[195:-1] - delta_std_ratio[195:-1],delta_mean_ratio[195:-1] + delta_std_ratio[195:-1], facecolor='xkcd:lightgreen')


#plt.legend(fontsize=14)
plt.ylim(0,3.5)
#xtick_positions=[0,99,167,217,317,367,433]
#xtick_labels=[1,100,150,218,100,150,216]
#plt.xticks(ticks=xtick_positions, labels=xtick_labels, fontsize=14)
plt.xticks([])
plt.yticks(fontsize=14)
#plt.xlabel('Residue index',fontsize=16)
#plt.ylabel('RMSF Ratio',fontsize=16)

plt.axvline(x=218,color='g')
plt.axvline(x=115)
plt.axvline(x=218+115)
plt.text(5,3,'Chain A',fontsize=16)
plt.text(120,3,'Chain A',fontsize=16)
plt.text(5+218,3,'Chain B',fontsize=16)
plt.text(120+218,3,'Chain B',fontsize=16)
plt.text(20,2.7,'ABD',fontsize=16)
plt.text(150,2.7,'DD',fontsize=16)
plt.text(20+218,2.7,'ABD',fontsize=16)
plt.text(150+218,2.7,'DD',fontsize=16)

plt.axhline(y=1.00,color='g',ls='--')
plt.savefig('rmsf_figures/7BZ5_Antibody_rmsf_ratio_saf.pdf',bbox_inches='tight')

# %%
xx = np.arange(433)

#plt.plot(xx,ind_mean_ratio[195:-1],'k-',label='Ind Variant')
#plt.fill_between(xx, ind_mean_ratio[195:-1] - ind_std_ratio[195:-1],ind_mean_ratio[195:-1] + ind_std_ratio[195:-1], facecolor='gray')

#plt.plot(xx,uk_mean_ratio[195:-1],'b-',label='UK Variant')
#plt.fill_between(xx, uk_mean_ratio[195:-1] - uk_std_ratio[195:-1],uk_mean_ratio[195:-1] + uk_std_ratio[195:-1], facecolor='xkcd:lightblue')

#plt.plot(xx,saf_mean_ratio[195:-1],'r-',label='SA Variant')
#plt.fill_between(xx, saf_mean_ratio[195:-1] - saf_std_ratio[195:-1],saf_mean_ratio[195:-1] + saf_std_ratio[195:-1], facecolor='pink')

plt.plot(xx,delta_mean_ratio[195:-1],'g-',label='delta Variant')
plt.fill_between(xx, delta_mean_ratio[195:-1] - delta_std_ratio[195:-1],delta_mean_ratio[195:-1] + delta_std_ratio[195:-1], facecolor='xkcd:lightgreen')


#plt.legend(fontsize=14)
plt.ylim(0,3.5)
xtick_positions=[0,99,167,217,317,367,433]
xtick_labels=[1,100,150,218,100,150,216]
plt.xticks(ticks=xtick_positions, labels=xtick_labels, fontsize=14)
#plt.xticks([])
plt.yticks(fontsize=14)
#plt.xlabel('Residue index',fontsize=16)
#plt.ylabel('RMSF Ratio',fontsize=16)

plt.axvline(x=218,color='g')
plt.axvline(x=115)
plt.axvline(x=218+115)
plt.text(5,3,'Chain A',fontsize=16)
plt.text(120,3,'Chain A',fontsize=16)
plt.text(5+218,3,'Chain B',fontsize=16)
plt.text(120+218,3,'Chain B',fontsize=16)
plt.text(20,2.7,'ABD',fontsize=16)
plt.text(150,2.7,'DD',fontsize=16)
plt.text(20+218,2.7,'ABD',fontsize=16)
plt.text(150+218,2.7,'DD',fontsize=16)

plt.axhline(y=1.00,color='g',ls='--')
plt.savefig('rmsf_figures/7BZ5_Antibody_rmsf_ratio_delta.pdf',bbox_inches='tight')

# %%
np.savetxt('rmsf_figures/uk_rmsf_ratio.dat',uk_mean_ratio,fmt='%0.2f')
np.savetxt('rmsf_figures/saf_rmsf_ratio.dat',saf_mean_ratio,fmt='%0.2f')
np.savetxt('rmsf_figures/ind_rmsf_ratio.dat',ind_mean_ratio,fmt='%0.2f')
np.savetxt('rmsf_figures/delta_rmsf_ratio.dat',delta_mean_ratio,fmt='%0.2f')
